# %%
from Core.PSMetric.FitnessQuality.SplitVariance import SplitVariance
from Core.PSMetric.SampleCount import SampleCount
from Core.PSMetric.FitnessQuality.SignificantlyHighAverage import MannWhitneyU
from Core.PSMetric.FitnessQuality.MeanFitness import MeanFitness
from Core.PSMetric.Simplicity import Simplicity
from Core.PSMetric.Linkage.ValueSpecificMutualInformation import FasterSolutionSpecificMutualInformation
from Core.PRef import PRef
from Core.FullSolution import FullSolution
from SimplifiedSystem.ps_search_utils import get_metric_function

def want_high(objective):
    def opposite(ps):
        return -objective(ps)

    return opposite

def want_low(objective):
    return objective

def metric_string_to_func(metric_string: str, pRef: PRef, linkage_evaluator: FasterSolutionSpecificMutualInformation):
    
    if metric_string == "simplicity":
        metric = Simplicity()
        return want_high(metric.get_single_score)
    if metric_string == "session_count":
        metric = SampleCount()
        metric.set_pRef(pRef)
        return want_high(metric.get_single_score)
    if metric_string == "mean_fitness":
        metric = MeanFitness()
        metric.set_pRef(pRef)
        return want_high(metric.get_single_score)
    if metric_string == "fitness_p_value":
        metric = MannWhitneyU()
        metric.set_pRef(pRef)
        return want_low(metric.get_single_score)
    
    if metric_string == "split_variance":
        metric = SplitVariance(selected_pRef=pRef)
        return want_low(metric.get_single_score)
    if metric_string == "atomicity":
        return want_high(linkage_evaluator.get_atomicity)
    if metric_string == "dependency":
        return want_low(linkage_evaluator.get_dependence)
    
    raise Exception(f"The metric {metric_string} not recognised")

# %%
from Core.PS import PS
import numpy as np
from Core.PRef import PRef
from Core.EvaluatedPS import EvaluatedPS

def get_quantile_of_mean_fitness(mean_fitness: float, pRef: PRef) -> float:
    """returns where the mean fitness lies in the distribution of fitnesses"""
    return np.sum(pRef.fitness_array <= mean_fitness) / pRef.sample_size
    
def ps_to_json(ps: EvaluatedPS, original_pRef: PRef):
    matched_sessions_fitnesses = original_pRef.fitnesses_of_observations(ps)
    mean_fitness = np.mean(matched_sessions_fitnesses)

    quantile = get_quantile_of_mean_fitness(mean_fitness, original_pRef)
        
    return {"pattern": repr(PS(ps.values)),
            "metrics": list(map(float,ps.metric_scores)), # might need to apply float to each
            "sample_count": len(matched_sessions_fitnesses),
            "mean_fitness": float(mean_fitness),
            "quartile_of_mean_fitness": float(quantile)
            }

# %%
from PolishSystem.read_data import get_pRef_from_vectors, get_vectors_file_name, get_fitness_file_name
from SimplifiedSystem.PSSearchSettings import get_default_search_settings, PSSearchSettings
from PolishSystem.polish_search_methods import search_local_polish_ps
import utils
from Core.PSMetric.Linkage.ValueSpecificMutualInformation import FasterSolutionSpecificMutualInformation
from SimplifiedSystem.ps_search_utils import apply_culling_method
from utils import announce

import json

data_folder = r"C:\Users\gac8\PycharmProjects\PSSearch\data\retail_forecasting"


def gather_data_for_settings(vector_sizes: list[int],
                             clustering_methods: list[str],
                             fitness_columns: list[int],
                             search_metrics_combinations: list[str],
                             qty_solutions_to_explain: int,
                             search_settings: PSSearchSettings,
                             output_file_name: str):
    results = []
    for vector_size in vector_sizes:
        for clustering_method in clustering_methods:
            for fitness_column in fitness_columns:
                pRef: PRef = get_pRef_from_vectors(get_vectors_file_name(data_folder, vector_size, clustering_method), 
                                         get_fitness_file_name(data_folder, vector_size, clustering_method), fitness_column)
                
                solutions_to_explain = [pRef.get_random_evaluated_fs() for _ in range(qty_solutions_to_explain)]
                
                for solution in solutions_to_explain:
                    with utils.announce(f"Calculating linkage information for {vector_size = }"):
                        linkage_evaluator = FasterSolutionSpecificMutualInformation()
                        linkage_evaluator.set_pRef(pRef)
                        linkage_evaluator.set_solution(solution)
                    for search_metrics in search_metrics_combinations:
                        search_metrics_as_functions = [metric_string_to_func(one_metric, pRef, linkage_evaluator) 
                                                        for one_metric in search_metrics.split()]
                        
                        def generate_datapoint():
                        
                            with announce(f"Searching for {vector_size = }, "
                                          f"{clustering_method = }, "
                                          f"{fitness_column = }, "
                                          f"{search_metrics =}"):
                                pss = search_local_polish_ps(solution_to_explain=solution,
                                                             search_settings=search_settings,
                                                             objectives = search_metrics_as_functions)
                                winning_ps = apply_culling_method(culling_method="elbow", pss=pss)[0]
                            
                            results.append({"vector_size": vector_size,
                                            "clustering_method": clustering_method,
                                            "fitness_column": fitness_column,
                                            "solution": repr(FullSolution(solution.values)),
                                            "solution_fitness": solution.fitness,
                                            "search_metrics": search_metrics,
                                            "resulting_pss": [ps_to_json(ps, pRef) for ps in pss],
                                            "winning_ps": ps_to_json(winning_ps, pRef)})
                        
                            
                        try:
                            generate_datapoint()
                        except Exception as e:
                            results.append({"error": True,
                                            "message": repr(e)})
    
    
    with utils.open_and_make_directories(output_file_name) as file:
        json.dump(results, file, indent=4)
        
    print(f"Saved the results to {output_file_name}")

# %%
vector_sizes = [20, 50, 100]
clustering_methods = ["qmc"]
fitness_columns = [0]
qty_solutions_to_explain = 12
search_metrics_combinations = ["simplicity mean_fitness atomicity", 
                               "session_count mean_fitness atomicity",  # simplicity   becomes session_count
                               "simplicity fitness_p_value atomicity",  # mean_fitness becomes fitness_p_value
                               "simplicity split_variance atomicity",   # mean_fitness becomes split_variance
                               "simplicity mean_fitness dependency",    # atomicity    becomes dependency
                               "mean_fitness atomicity dependency"      # removed mean_fitness, added dependency
                               ]

def get_file_destination_name(extra_info):
    return r"C:\Users\gac8\PycharmProjects\PSSearch\PolishSystem\DataCollection\results\pss"+extra_info+utils.get_formatted_timestamp()+".json"


search_settings = get_default_search_settings()
search_settings.metrics = None # just in case
search_settings.verbose = True # because it's annoying
search_settings.culling_method = None # because I want to capture the entire pareto front

for vector_size in vector_sizes:
    gather_data_for_settings(vector_sizes = [vector_size],
                             clustering_methods=clustering_methods,
                             fitness_columns=fitness_columns,
                             search_metrics_combinations=search_metrics_combinations,
                             search_settings=search_settings,
                             qty_solutions_to_explain=qty_solutions_to_explain,
                             output_file_name=get_file_destination_name(extra_info=f"vector_size_{vector_size}_")
                             )
# Out:
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.582144 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# ...Finished (took 0.587852 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * 1 1 * * * * * * * * * * * * *][-18.000, 0.000, 0.002, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.005, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# ...Finished (took 0.682822 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * 1 1 * * * * * * * * * * * * *][-18.000, 0.034, 0.002, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.005, ]
# ...Finished (took 0.673706 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.482650 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        4 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# ...Finished (took 0.578532 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       38 |     10 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     11 |  0.000000E+00 |  0.000000E+00 |  0.0918345713 |             f
#      3 |       64 |     11 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-19.000, -0.876, 0.002, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * 1 * *][-17.000, -0.881, -0.009, ]
# 	 [* * * * * 1 * * 1 * * * 1 * * * * 1 * *][-16.000, -0.883, -0.006, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.005, ]
# 	 [* * * * * 1 1 * 1 * * * 1 * * * * 1 * *][-15.000, -0.883, -0.003, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, -0.873, -0.023, ]
# 	 [* * * * * * * * 1 * * * 1 1 * * * 1 * *][-16.000, -0.881, -0.007, ]
# 	 [* * * * * * * * 1 * * * * * * * * 1 * *][-18.000, -0.878, -0.011, ]
# 	 [* * * * * * * * * * * * 1 * * * * 1 * *][-18.000, -0.878, -0.009, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * * * *][-18.000, -0.877, -0.020, ]
# ...Finished (took 1.100579 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       38 |     13 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     16 |  0.000000E+00 |  0.000000E+00 |  0.0396628035 |             f
#      3 |       64 |     16 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-11701.000, -0.876, 0.002, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * * * *][-4561.000, -0.877, -0.020, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-16842.000, -0.877, 0.005, ]
# 	 [* * * * * * * * * * * * 1 * * * * 1 * *][-1095.000, -0.878, -0.009, ]
# 	 [* * * * * 1 * * 1 * * * 1 * * * * 1 * *][-514.000, -0.883, -0.006, ]
# 	 [* * * * * * * * 1 * * * * * * * * 1 * *][-896.000, -0.878, -0.011, ]
# 	 [* * * * * 1 1 * 1 * * * 1 * * * * 1 * *][-480.000, -0.883, -0.003, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-9097.000, -0.873, -0.023, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-28686.000, -0.870, -0.010, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * 1 * *][-816.000, -0.880, -0.006, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-12026.000, -0.874, -0.018, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-13606.000, -0.875, -0.011, ]
# 	 [* * * * * 1 * * 1 * * * * 1 * * * 1 * *][-762.000, -0.879, -0.006, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * 1 * *][-538.000, -0.881, -0.009, ]
# 	 [* * * * * * * * 1 * * * 1 1 * * * 1 * *][-513.000, -0.881, -0.007, ]
# ...Finished (took 1.249932 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       41 |      9 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     10 |  0.000000E+00 |  0.000000E+00 |  0.3333333333 |         nadir
#      3 |       64 |     10 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.246, -0.023, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, 0.000, -0.011, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.000, -0.010, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.001, ]
# 	 [* * * * * * * * * * * * * * * * * 1 * *][-19.000, 0.000, 0.001, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-18.000, 0.000, -0.018, ]
# 	 [* * * * * * * * 1 * * * * * * * * 1 * *][-18.000, 0.000, -0.011, ]
# 	 [* * * * * * * * * * * * 1 * * * * 1 * *][-18.000, 0.000, -0.009, ]
# 	 [* * * * * * 1 * * * * * * 1 * * * 1 * *][-17.000, 0.000, -0.004, ]
# ...Finished (took 1.091901 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       37 |      7 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.1939725133 |         ideal
#      3 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.003, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.001, ]
# 	 [* * * * * * 1 * * * * * * 1 * * * * * *][-18.000, 0.034, -0.004, ]
# 	 [* * * * * * * * * * * * * * * * * 1 * *][-19.000, 0.034, 0.001, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.034, -0.010, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.034, -0.023, ]
# ...Finished (took 0.954191 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       41 |      9 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     12 |  0.000000E+00 |  0.000000E+00 |  0.0438396470 |             f
#      3 |       64 |     12 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.020, ]
# 	 [* * * * * 1 1 * 1 * * * 1 1 * * * 1 * *][-14.000, -0.881, 0.000, ]
# 	 [* * * * * 1 * * 1 * * * 1 * * * * 1 * *][-16.000, -0.883, 0.014, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * 1 * *][-17.000, -0.880, 0.014, ]
# 	 [* * * * * 1 1 * 1 * * * 1 * * * * 1 * *][-15.000, -0.883, 0.010, ]
# 	 [* * * * * * * * 1 * * * 1 1 * * * 1 * *][-16.000, -0.881, 0.010, ]
# 	 [* * * * * * 1 * 1 * * * 1 1 * * * 1 * *][-15.000, -0.881, 0.007, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * 1 * *][-17.000, -0.877, 0.013, ]
# 	 [* * * * * * 1 * 1 * * * 1 * * * * 1 * *][-16.000, -0.882, 0.011, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * 1 * *][-17.000, -0.881, 0.015, ]
# 	 [* * * * * * * * * * * * 1 * * * * 1 * *][-18.000, -0.878, 0.015, ]
# ...Finished (took 1.108763 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       34 |     13 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     21 |  0.000000E+00 |  0.000000E+00 |  0.1595785048 |         ideal
#      3 |       64 |     21 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * * * * 1 * * * * * * * * 1 * *][-0.878, -0.011, 0.016, ]
# 	 [* * * * * 1 1 * 1 * * * 1 1 * * * 1 * *][-0.881, -0.003, 0.000, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * * * *][-0.877, -0.020, 0.020, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-0.874, -0.018, 0.014, ]
# 	 [* * * * * 1 * * 1 * * * 1 1 * * * * * *][-0.873, -0.008, 0.010, ]
# 	 [* * * * * * 1 * 1 * * * 1 * * * * * * *][-0.873, -0.012, 0.013, ]
# 	 [* * * * * * * * * * * * 1 * * * * 1 * *][-0.878, -0.009, 0.015, ]
# 	 [* * * * * 1 1 * 1 * * * 1 1 * * * * * *][-0.871, -0.003, 0.007, ]
# 	 [* * * * * * 1 * 1 * * * 1 1 * * * * * *][-0.870, -0.006, 0.009, ]
# 	 [* * * * * 1 1 * 1 * * * 1 * * * * 1 * *][-0.883, -0.003, 0.010, ]
# 	 [* * * * * 1 * * 1 * * * 1 * * * * 1 * *][-0.883, -0.006, 0.014, ]
# 	 [* * * * * * * * 1 * * * 1 1 * * * * * *][-0.873, -0.011, 0.013, ]
# 	 [* * * * * 1 * * 1 * * * 1 1 * * * 1 * *][-0.881, -0.006, 0.008, ]
# 	 [* * * * * * 1 * 1 * * * 1 * * * * 1 * *][-0.882, -0.006, 0.011, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-0.873, -0.023, 0.015, ]
# 	 [* * * * * * * * 1 * * * 1 1 * * * 1 * *][-0.881, -0.007, 0.010, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-0.875, -0.011, 0.015, ]
# 	 [* * * * * * * * 1 * * * 1 * * * * 1 * *][-0.881, -0.009, 0.015, ]
# 	 [* * * * * * 1 * 1 * * * 1 1 * * * 1 * *][-0.881, -0.005, 0.007, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * 1 * *][-0.877, -0.008, 0.013, ]
# ...Finished (took 1.063956 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-18.000, -0.875, -0.009, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, -0.873, -0.023, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-19.000, -0.876, 0.006, ]
# ...Finished (took 0.596782 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-9482.000, -0.875, -0.009, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-9097.000, -0.873, -0.023, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-11701.000, -0.876, 0.006, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-28686.000, -0.870, -0.010, ]
# ...Finished (took 0.629945 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.003, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.000, -0.010, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.246, -0.023, ]
# ...Finished (took 0.571069 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.034, -0.023, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.034, -0.010, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.003, ]
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.005, ]
# ...Finished (took 0.602627 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      2 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-19.000, -0.876, 0.023, ]
# ...Finished (took 0.572333 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-0.876, 0.006, 0.023, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-0.875, -0.009, 0.016, ]
# 	 [* * * * * 1 * * 1 * * * * 1 * * * * * *][-0.873, -0.009, 0.001, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-0.873, -0.023, 0.009, ]
# ...Finished (took 0.593261 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       28 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       32 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * 1 * * * * *][-18.000, -0.871, -0.026, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-18.000, -0.874, -0.018, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.006, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, -0.875, -0.011, ]
# ...Finished (took 1.126356 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       28 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       32 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-16842.000, -0.877, 0.006, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-12026.000, -0.874, -0.018, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-13606.000, -0.875, -0.011, ]
# 	 [* * * * * * * * * * * * 1 * 1 * * * * *][-4272.000, -0.871, -0.026, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-28686.000, -0.870, -0.010, ]
# ...Finished (took 1.212775 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       30 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       32 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-18.000, 0.000, -0.018, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.001, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.000, -0.010, ]
# 	 [* * * * * * * * * * * * 1 * 1 * * * * *][-18.000, 0.328, -0.026, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, 0.000, -0.011, ]
# ...Finished (took 1.152500 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       26 |      7 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |      8 |  0.000000E+00 |  0.000000E+00 |  0.3333333333 |         nadir
#      3 |       32 |      8 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * 1 * * * * *][-18.000, 0.034, -0.026, ]
# 	 [* * * * * * * * * * * * * 1 1 * * * * *][-18.000, 0.034, -0.018, ]
# 	 [* * * * * * 1 * * * * * * 1 * * * * * *][-18.000, 0.034, -0.004, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.001, ]
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.004, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.034, -0.010, ]
# 	 [* * * * * 1 * * * * * * * 1 1 * * * * *][-17.000, 0.034, -0.011, ]
# ...Finished (took 0.990807 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       26 |      2 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       32 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.026, ]
# ...Finished (took 1.134066 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       28 |     14 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       32 |     14 |  0.000000E+00 |  0.000000E+00 |  0.0184777032 |             f
#      3 |       32 |     14 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * * 1 * * * * * 1 * * * * * * *][-0.874, -0.018, 0.021, ]
# 	 [* * * * * 1 * * * * * * 1 * 1 * * * * *][-0.869, -0.012, 0.015, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-0.877, 0.006, 0.026, ]
# 	 [* * * * * * * * * * * * 1 * 1 * * * * *][-0.871, -0.026, 0.018, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-0.875, -0.011, 0.020, ]
# 	 [* * * * * 1 1 * * * * * 1 1 1 * * * * *][-0.864, -0.005, 0.001, ]
# 	 [* * * * * 1 1 * * * * * 1 * * * * * * *][-0.872, -0.002, 0.019, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-0.870, -0.010, 0.016, ]
# 	 [* * * * * 1 1 * * * * * 1 * 1 * * * * *][-0.867, -0.006, 0.010, ]
# 	 [* * * * * * 1 * * * * * 1 1 1 * * * * *][-0.864, -0.008, 0.009, ]
# 	 [* * * * * * * * * * * * * 1 1 * * * * *][-0.867, -0.018, 0.018, ]
# 	 [* * * * * 1 * * * * * * 1 1 1 * * * * *][-0.865, -0.010, 0.011, ]
# 	 [* * * * * * 1 * * * * * 1 * 1 * * * * *][-0.867, -0.017, 0.011, ]
# ...Finished (took 1.018713 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.433577 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# ...Finished (took 0.438195 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      2 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.005, ]
# ...Finished (took 0.738531 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      2 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.005, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# ...Finished (took 0.741219 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.439014 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        2 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# ...Finished (took 0.437313 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.010, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, -0.875, -0.011, ]
# ...Finished (took 0.607962 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-28686.000, -0.870, -0.010, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-16842.000, -0.877, 0.010, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-13606.000, -0.875, -0.011, ]
# ...Finished (took 0.636347 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.003, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.000, -0.010, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, 0.000, -0.011, ]
# ...Finished (took 0.573493 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.007, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-18.000, 0.034, -0.010, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.034, 0.003, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-18.000, 0.034, -0.011, ]
# ...Finished (took 0.572439 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      2 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-19.000, -0.877, 0.011, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.649499 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * 1 * * * * * * 1 1 * * * * * *][-0.871, -0.008, 0.001, ]
# 	 [* * * * * * * * * * * * 1 * * * * * * *][-0.877, 0.010, 0.011, ]
# 	 [* * * * * 1 * * * * * * 1 * * * * * * *][-0.875, -0.011, 0.008, ]
# ...Finished (took 0.607780 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       41 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       64 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, -0.873, -0.023, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-19.000, -0.876, 0.002, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-18.000, -0.875, -0.009, ]
# ...Finished (took 1.207985 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       34 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.0890076175 |             f
#      3 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-9097.000, -0.873, -0.023, ]
# 	 [* * * * * * * * * * * * * 1 * * 1 * * *][-16537.000, -0.860, -0.013, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-11701.000, -0.876, 0.002, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-9482.000, -0.875, -0.009, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-28686.000, -0.870, -0.010, ]
# 	 [* * * * * * 1 * * * * * * * * * 1 * * *][-15961.000, -0.866, -0.018, ]
# ...Finished (took 1.291260 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       36 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.0565033944 |         ideal
#      3 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * * 1 * * * * * * * * * * * * *][-19.000, 0.000, 0.002, ]
# 	 [* * * * * * * * * * 1 * * 1 * * 1 * * *][-17.000, 0.000, -0.014, ]
# 	 [* * * * * 1 * * * * * * * * * * * * * *][-19.000, 0.000, 0.003, ]
# 	 [* * * * * * * * * * 1 * * * * * 1 * * *][-18.000, 0.000, -0.021, ]
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.000, 0.002, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.246, -0.023, ]
# ...Finished (took 1.124068 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       41 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.0203533819 |         ideal
#      3 |       64 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * * * * * * 1 * * 1 * * 1 * * *][-17.000, 0.034, -0.014, ]
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.002, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-18.000, 0.034, -0.023, ]
# 	 [* * * * * * * * * * * * * 1 * * 1 * * *][-18.000, 0.034, -0.013, ]
# 	 [* * * * * * * * * * 1 * * * * * 1 * * *][-18.000, 0.034, -0.021, ]
# 	 [* * * * * 1 * * * * * * * 1 * * 1 * * *][-17.000, 0.034, -0.001, ]
# ...Finished (took 0.982155 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       30 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       64 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * 1 1 * 1 * 1 * * 1 * * 1 * * *][-14.000, -0.848, -0.000, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-19.000, -0.876, 0.023, ]
# ...Finished (took 1.119775 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       40 |      9 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       64 |     12 |  0.000000E+00 |  0.000000E+00 |  0.0099111196 |         ideal
#      3 |       64 |     12 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * * * * 1 * * * * 1 * * * * * *][-0.873, -0.023, 0.016, ]
# 	 [* * * * * * * * 1 * * * * * * * * * * *][-0.876, 0.002, 0.023, ]
# 	 [* * * * * 1 * * 1 * * * * * * * * * * *][-0.875, -0.009, 0.016, ]
# 	 [* * * * * * 1 * * * * * * * * * 1 * * *][-0.866, -0.018, 0.015, ]
# 	 [* * * * * 1 * * * * * * * 1 * * * * * *][-0.870, -0.010, 0.016, ]
# 	 [* * * * * 1 * * 1 * * * * 1 * * * * * *][-0.873, -0.009, 0.013, ]
# 	 [* * * * * * * * 1 * 1 * * 1 * * 1 * * *][-0.851, -0.014, 0.011, ]
# 	 [* * * * * 1 * * 1 * 1 * * 1 * * * * * *][-0.857, -0.008, 0.012, ]
# 	 [* * * * * 1 1 * 1 * 1 * * 1 * * 1 * * *][-0.848, -0.002, -0.000, ]
# 	 [* * * * * * 1 * 1 * 1 * * * * * 1 * * *][-0.853, -0.010, 0.014, ]
# 	 [* * * * * * 1 * 1 * 1 * * 1 * * 1 * * *][-0.851, -0.008, 0.005, ]
# ...Finished (took 1.045316 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * 1 * * * * 1 * * * *][-18.000, -0.865, -0.016, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-18.000, -0.870, -0.007, ]
# ...Finished (took 0.671393 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * * * * * 1 * * * * 1 * * * *][-1758.000, -0.865, -0.016, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-6563.000, -0.870, -0.007, ]
# 	 [* * * * * * 1 * * * 1 * * * * * * * * *][-4673.000, -0.854, -0.009, ]
# ...Finished (took 0.680197 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * 1 * * * * * * * * * * * * *][-19.000, 0.000, 0.004, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * * * * * * * * * 1 * * * * 1 * * * *][-18.000, 0.000, -0.016, ]
# ...Finished (took 0.612048 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * * * * * 1 * * * * * * * * * * * * *][-19.000, 0.034, 0.004, ]
# 	 [* * * * * * * * * * 1 * * * * * * * * *][-19.000, 0.034, 0.006, ]
# 	 [* * * * * * * * * * 1 * * * * 1 * * * *][-18.000, 0.034, -0.016, ]
# 	 [* * * * * * 1 * * * 1 * * * * * * * * *][-18.000, 0.034, -0.009, ]
# ...Finished (took 0.575799 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.537058 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |        8 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * 1 * * * 1 * * * * 1 * * * *][-0.860, -0.007, 0.000, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-0.870, -0.007, 0.012, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * * * * * * * * * 1 * * * * 1 * * * *][-0.865, -0.016, 0.008, ]
# ...Finished (took 0.618815 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       16 |      3 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |       16 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-18.000, -0.870, -0.007, ]
# 	 [* * * * * * * * * * * * * 1 * 1 * * * *][-18.000, -0.869, -0.016, ]
# ...Finished (took 0.557169 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='session_count mean_fitness atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       15 |      4 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       16 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      3 |       16 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-52626.000, -0.876, 0.000, ]
# 	 [* * * * * * 1 * * * * * * 1 * * * * * *][-24321.000, -0.869, -0.004, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-6563.000, -0.870, -0.007, ]
# 	 [* * * * * * * * * * * * * 1 * 1 * * * *][-7274.000, -0.869, -0.016, ]
# ...Finished (took 1.206559 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity fitness_p_value atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       15 |      5 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |  0.0003637066 |             f
#      3 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |  0.0003637066 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 1.000, 0.000, ]
# 	 [* * 1 * * * * * * * * * * 1 * * * * * *][-18.000, 0.000, -0.015, ]
# 	 [* * * * * * 1 * * * * * * * * * * * * *][-19.000, 0.000, 0.004, ]
# 	 [* * 1 * * * * * * * * * * 1 * 1 * * * *][-17.000, 0.000, -0.015, ]
# 	 [* * * * * * * * * * * * * 1 * 1 * * * *][-18.000, 0.000, -0.016, ]
# 	 [* * 1 * * * * * * * * * * * * 1 * * * *][-18.000, 0.000, -0.015, ]
# ...Finished (took 1.221309 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity split_variance atomicity'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       15 |      9 |  0.000000E+00 |  0.000000E+00 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |  0.0832875938 |         ideal
#      3 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * 1 * * * * * * * * * * * * *][-19.000, 0.034, 0.004, ]
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, 0.034, 0.000, ]
# 	 [* * 1 * * * * * * * * * * * * * * * * *][-19.000, 0.034, 0.006, ]
# 	 [* * * * * * * * * * * * * 1 * * * * * *][-19.000, 0.034, 0.005, ]
# 	 [* * * * * * * * * * * * * 1 * 1 * * * *][-18.000, 0.034, -0.016, ]
# 	 [* * 1 * * * * * * * * * * 1 * * * * * *][-18.000, 0.034, -0.015, ]
# ...Finished (took 1.071577 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='simplicity mean_fitness dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       16 |      1 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |       16 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-20.000, -0.876, 0.000, ]
# ...Finished (took 0.519235 seconds)
# Searching for vector_size = 20, clustering_method = 'qmc', fitness_column = 0, search_metrics ='mean_fitness atomicity dependency'...==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |       16 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
# The pss found in the search are
# 	 [* * * * * * * * * * * * * * * * * * * *][-0.876, 0.000, 0.000, ]
# 	 [* * 1 * * * * * * * * * * 1 * 1 * * * *][-0.854, -0.015, 0.007, ]
# 	 [* * * * * * 1 * * * * * * * * 1 * * * *][-0.870, -0.007, 0.013, ]
# 	 [* * 1 * * * 1 * * * * * * 1 * 1 * * * *][-0.851, -0.006, 0.000, ]
# 	 [* * 1 * * * 1 * * * * * * * * 1 * * * *][-0.857, -0.008, 0.012, ]
# 	 [* * * * * * * * * * * * * 1 * 1 * * * *][-0.869, -0.016, 0.015, ]
# ...Finished (took 0.516018 seconds)
