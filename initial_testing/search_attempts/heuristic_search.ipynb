# %%
from BenchmarkProblems.Checkerboard import CheckerBoard
from BenchmarkProblems.GraphColouring import GraphColouring
from BenchmarkProblems.Trapk import Trapk
from Core.get_pRef import get_pRef_from_metaheuristic
# Check that reference populations and metrics work as intended

from Core.FullSolution import FullSolution
from Core.PS import PS, contains, STAR
from BenchmarkProblems.RoyalRoad import RoyalRoad

# first, we make a benchmark problem
problem = RoyalRoad(5)

# then we make a pRef
pRef = get_pRef_from_metaheuristic(problem=problem,
                                   sample_size=10000,
                                   which_algorithm="GA uniform",
                                   unique=True,
                                   verbose=True)

# we can remove duplicated_entries (recommended)


print(f"Generated the PRef: {pRef}")
# Out:
# Running the algorithm to generate the PRef using GA......Finished (took 0.542422 seconds)
# Running the algorithm to generate the PRef using uniform......Finished (took 0.288718 seconds)
# Generated the PRef: PRef with 5759 samples, mean = 2.18

# %%
from Core.PRef import PRef
from typing import Optional
from Core.EvaluatedFS import EvaluatedFS
import numpy as np


def get_quality(wins: int, losses: int) -> Optional[float]:
    if wins+losses == 0:
        return -1
    else:
        return wins / (wins+losses)
    


def add_pss(ps_a: PS, ps_b: PS) -> PS:
    return PS(from_a if from_a != STAR else from_b for from_a, from_b in zip(ps_a.values, ps_b.values))


def minus_pss(ps_a: PS, ps_b: PS) -> PS:
    return PS(from_a if from_b == STAR else STAR for from_a, from_b in zip(ps_a.values, ps_b.values))
    
    
def get_wins_and_losses_for_solution_and_ps(solution: EvaluatedFS, ps: PS, non_matching_pRef: PRef) -> (int, int):
    # find the solutions that are similar to s, but without the pattern ps
    pattern_solution_minus_ps = minus_pss(PS.from_FS(solution), ps)
    
    fitnesses_without_ps = non_matching_pRef.fitnesses_of_observations(pattern_solution_minus_ps)
    if len(fitnesses_without_ps) == 0:
        return (0, 0)
    

    wins = np.sum(fitnesses_without_ps < solution.fitness)
    losses = np.sum(fitnesses_without_ps > solution.fitness)
    return wins, losses


def get_total_wins_and_losses_for_ps(ps: PS):
    wins, losses = (0,0)
    indexes_of_ps = pRef.get_indexes_matching_ps(ps)
    matching_pRef, non_matching_pRef = pRef.split_by_indexes(indexes_of_ps)
    for solution in matching_pRef.get_evaluated_FSs():
        new_wins, new_losses = get_wins_and_losses_for_solution_and_ps(solution, ps, non_matching_pRef)
        wins += new_wins
        losses += new_losses
        
    return wins, losses


def get_quality_of_ps(ps: PS) -> float:
    wins, losses = get_total_wins_and_losses_for_ps(ps)
    
    if wins+losses == 0:
        return -1
    
    #before = wins / (wins+losses)
    after = wins / (wins+losses+1)
    return after

# %%
random_pss = [PS.random_with_fixed_size(problem.search_space, size=5) for _ in range(100)]

random_pss.extend(problem.get_targets())

random_pss.sort(key=get_quality_of_ps, reverse=True)

for ps in random_pss:
    qual = get_quality_of_ps(ps)
    wins, losses = get_total_wins_and_losses_for_ps(ps)
    print(f"The ps is {ps}, it has quality {qual}, {wins =}, {losses = }")
    print(problem.repr_ps(ps))
# Out:
# The ps is [1 1 1 1 * * * * * * * * * * * * * * * *], it has quality 0.996078431372549, wins =254, losses = 0
# [1 1 1 1  * * * *  * * * *  * * * *  * * * *]
# The ps is [* * * * * * * * * 1 1 1 * * * * * 1 1 *], it has quality 0.996, wins =249, losses = 0
# [* * * *  * * * *  * 1 1 1  * * * *  * 1 1 *]
# The ps is [* * * * * * * * * * * * * * * * 1 1 1 1], it has quality 0.9959183673469387, wins =244, losses = 0
# [* * * *  * * * *  * * * *  * * * *  1 1 1 1]
# The ps is [* * * * * * * * * * * * * 1 1 1 1 * * 1], it has quality 0.9957264957264957, wins =233, losses = 0
# [* * * *  * * * *  * * * *  * 1 1 1  1 * * 1]
# The ps is [* * * * * * * * 1 1 1 1 * * * * * * * *], it has quality 0.9955947136563876, wins =226, losses = 0
# [* * * *  * * * *  1 1 1 1  * * * *  * * * *]
# The ps is [* * * * * * * * * * * * 1 1 1 1 * * * *], it has quality 0.9954954954954955, wins =221, losses = 0
# [* * * *  * * * *  * * * *  1 1 1 1  * * * *]
# The ps is [* * * * 1 1 1 1 * * * * * * * * * * * *], it has quality 0.9954128440366973, wins =217, losses = 0
# [* * * *  1 1 1 1  * * * *  * * * *  * * * *]
# The ps is [* * * 1 * * 1 * * * 1 * 1 * * 1 * * * *], it has quality 0.995049504950495, wins =201, losses = 0
# [* * * 1  * * 1 *  * * 1 *  1 * * 1  * * * *]
# The ps is [* 1 1 * * 1 * * * * * * * 1 * * * * 1 *], it has quality 0.9948979591836735, wins =195, losses = 0
# [* 1 1 *  * 1 * *  * * * *  * 1 * *  * * 1 *]
# The ps is [* * * 1 * * * * * * 1 * * 1 * * 0 * 0 *], it has quality 0.8043478260869565, wins =37, losses = 8
# [* * * 1  * * * *  * * 1 *  * 1 * *  0 * 0 *]
# The ps is [1 * * 1 * * * * * * * * 0 * * 0 * * * 1], it has quality 0.75, wins =15, losses = 4
# [1 * * 1  * * * *  * * * *  0 * * 0  * * * 1]
# The ps is [* * 0 * * * * 1 1 1 * * * * * 1 * * * *], it has quality 0.7102803738317757, wins =76, losses = 30
# [* * 0 *  * * * 1  1 1 * *  * * * 1  * * * *]
# The ps is [* * * 1 * * * * * 1 1 * * * 0 * 1 * * *], it has quality 0.6962025316455697, wins =55, losses = 23
# [* * * 1  * * * *  * 1 1 *  * * 0 *  1 * * *]
# The ps is [* * * 0 * 1 * * * 1 * * * 1 * * * * 1 *], it has quality 0.6792452830188679, wins =72, losses = 33
# [* * * 0  * 1 * *  * 1 * *  * 1 * *  * * 1 *]
# The ps is [* * * 0 * * 1 * * 1 * 1 * * * 1 * * * *], it has quality 0.6752136752136753, wins =79, losses = 37
# [* * * 0  * * 1 *  * 1 * 1  * * * 1  * * * *]
# The ps is [0 * * * * 1 * 1 * * * * * * 1 * 1 * * *], it has quality 0.6666666666666666, wins =50, losses = 24
# [0 * * *  * 1 * 1  * * * *  * * 1 *  1 * * *]
# The ps is [0 * * 0 * * * 1 1 * * * * * * * * 1 * *], it has quality 0.65625, wins =21, losses = 10
# [0 * * 0  * * * 1  1 * * *  * * * *  * 1 * *]
# The ps is [* * * * * * * 1 * * * 0 * * * 1 1 * 1 *], it has quality 0.6483516483516484, wins =59, losses = 31
# [* * * *  * * * 1  * * * 0  * * * 1  1 * 1 *]
# The ps is [1 * * * * * 1 * * 0 * * * * * * 1 * 1 *], it has quality 0.6352941176470588, wins =54, losses = 30
# [1 * * *  * * 1 *  * 0 * *  * * * *  1 * 1 *]
# The ps is [* * 1 * * * * * * 0 * * * 1 * * 1 * 1 *], it has quality 0.6352941176470588, wins =54, losses = 30
# [* * 1 *  * * * *  * 0 * *  * 1 * *  1 * 1 *]
# The ps is [0 * 1 * * * * * * * * * 1 * * * 1 * 1 *], it has quality 0.6153846153846154, wins =40, losses = 24
# [0 * 1 *  * * * *  * * * *  1 * * *  1 * 1 *]
# The ps is [0 0 * * * * * * * * * 1 1 * * * * * 1 *], it has quality 0.6153846153846154, wins =16, losses = 9
# [0 0 * *  * * * *  * * * 1  1 * * *  * * 1 *]
# The ps is [* * * * 1 1 * * * * * * 1 * 0 * 1 * * *], it has quality 0.5970149253731343, wins =40, losses = 26
# [* * * *  1 1 * *  * * * *  1 * 0 *  1 * * *]
# The ps is [0 * * 0 * 1 1 * * * * * * * * 1 * * * *], it has quality 0.59375, wins =19, losses = 12
# [0 * * 0  * 1 1 *  * * * *  * * * 1  * * * *]
# The ps is [* 1 * 1 1 * * * * * * 0 * * * * * * * 1], it has quality 0.5853658536585366, wins =48, losses = 33
# [* 1 * 1  1 * * *  * * * 0  * * * *  * * * 1]
# The ps is [* 1 0 * 1 * * * * 1 * * * 1 * * * * * *], it has quality 0.573170731707317, wins =47, losses = 34
# [* 1 0 *  1 * * *  * 1 * *  * 1 * *  * * * *]
# The ps is [* * * * * * * * 1 * * * * * 1 1 * * 1 0], it has quality 0.559322033898305, wins =33, losses = 25
# [* * * *  * * * *  1 * * *  * * 1 1  * * 1 0]
# The ps is [* 1 1 * * * * * * * * * * * * * 0 1 0 *], it has quality 0.5454545454545454, wins =18, losses = 14
# [* 1 1 *  * * * *  * * * *  * * * *  0 1 0 *]
# The ps is [1 * * * * * 1 0 * * * 1 * * * * 1 * * *], it has quality 0.5454545454545454, wins =36, losses = 29
# [1 * * *  * * 1 0  * * * 1  * * * *  1 * * *]
# The ps is [* 1 * * * * * 0 * * * * 1 * * * * 1 * 1], it has quality 0.5375, wins =43, losses = 36
# [* 1 * *  * * * 0  * * * *  1 * * *  * 1 * 1]
# The ps is [* 1 * * 1 * * * 0 * * 0 * * * * * * 1 *], it has quality 0.5263157894736842, wins =10, losses = 8
# [* 1 * *  1 * * *  0 * * 0  * * * *  * * 1 *]
# The ps is [* * * * * * * * * 1 * 0 1 * * * 1 * 1 *], it has quality 0.5217391304347826, wins =36, losses = 32
# [* * * *  * * * *  * 1 * 0  1 * * *  1 * 1 *]
# The ps is [* * * * * 0 * * * * * 1 1 * * 1 * * * 1], it has quality 0.5070422535211268, wins =36, losses = 34
# [* * * *  * 0 * *  * * * 1  1 * * 1  * * * 1]
# The ps is [* * 0 * * 1 * 1 * * * * * * * * 0 * 0 *], it has quality 0.5, wins =9, losses = 8
# [* * 0 *  * 1 * 1  * * * *  * * * *  0 * 0 *]
# The ps is [0 * * * * * * * * * * * 0 * 1 0 * * * 1], it has quality 0.5, wins =2, losses = 1
# [0 * * *  * * * *  * * * *  0 * 1 0  * * * 1]
# The ps is [1 * * * * 1 * * 0 * * 0 * * 1 * * * * *], it has quality 0.5, wins =9, losses = 8
# [1 * * *  * 1 * *  0 * * 0  * * 1 *  * * * *]
# The ps is [1 0 1 * * 1 * * * * * * * * * * * * 1 *], it has quality 0.4, wins =26, losses = 38
# [1 0 1 *  * 1 * *  * * * *  * * * *  * * 1 *]
# The ps is [* 0 * * 1 * * * * * * 0 * * * * * * 1 1], it has quality 0.34782608695652173, wins =16, losses = 29
# [* 0 * *  1 * * *  * * * 0  * * * *  * * 1 1]
# The ps is [* 0 * * * 1 * * * * * * 1 * 0 * * * 0 *], it has quality 0.3333333333333333, wins =3, losses = 5
# [* 0 * *  * 1 * *  * * * *  1 * 0 *  * * 0 *]
# The ps is [1 * * * * * 0 * * * * 0 0 * * * 1 * * *], it has quality 0.3333333333333333, wins =5, losses = 9
# [1 * * *  * * 0 *  * * * 0  0 * * *  1 * * *]
# The ps is [* * 1 1 * 0 * * * * * 1 * * * * * * 0 *], it has quality 0.3125, wins =5, losses = 10
# [* * 1 1  * 0 * *  * * * 1  * * * *  * * 0 *]
# The ps is [* 1 * * * 0 * * 1 * * 1 0 * * * * * * *], it has quality 0.3076923076923077, wins =8, losses = 17
# [* 1 * *  * 0 * *  1 * * 1  0 * * *  * * * *]
# The ps is [* * * 0 * * * * * 1 * * * 1 * * 0 * * 0], it has quality 0.3076923076923077, wins =4, losses = 8
# [* * * 0  * * * *  * 1 * *  * 1 * *  0 * * 0]
# The ps is [0 * * * * 1 * * 1 * * * * 1 * * * * * 0], it has quality 0.30303030303030304, wins =10, losses = 22
# [0 * * *  * 1 * *  1 * * *  * 1 * *  * * * 0]
# The ps is [* 0 * * * * * 1 * 0 * * * * 1 * * * * 1], it has quality 0.3, wins =12, losses = 27
# [* 0 * *  * * * 1  * 0 * *  * * 1 *  * * * 1]
# The ps is [* * 1 * * * 0 * 0 * * 1 * * * * * * * 1], it has quality 0.3, wins =6, losses = 13
# [* * 1 *  * * 0 *  0 * * 1  * * * *  * * * 1]
# The ps is [* * 0 * 1 * * * * * * * * 1 * 1 * * 0 *], it has quality 0.2972972972972973, wins =11, losses = 25
# [* * 0 *  1 * * *  * * * *  * 1 * 1  * * 0 *]
# The ps is [* * 1 * * * 0 0 0 * * * * * * * * 1 * *], it has quality 0.2857142857142857, wins =2, losses = 4
# [* * 1 *  * * 0 0  0 * * *  * * * *  * 1 * *]
# The ps is [* * * * * * * 0 * 1 1 * * * * * 1 * 0 *], it has quality 0.2682926829268293, wins =11, losses = 29
# [* * * *  * * * 0  * 1 1 *  * * * *  1 * 0 *]
# The ps is [* * * * 0 * * * * * 0 * * * 0 0 * * * 1], it has quality 0.26666666666666666, wins =4, losses = 10
# [* * * *  0 * * *  * * 0 *  * * 0 0  * * * 1]
# The ps is [* 1 * * * * * * 0 * 0 * * 1 * * * 0 * *], it has quality 0.26666666666666666, wins =4, losses = 10
# [* 1 * *  * * * *  0 * 0 *  * 1 * *  * 0 * *]
# The ps is [* 1 1 * * 0 * * * * * * * * 1 0 * * * *], it has quality 0.25925925925925924, wins =7, losses = 19
# [* 1 1 *  * 0 * *  * * * *  * * 1 0  * * * *]
# The ps is [1 * * * * 0 0 * * * * 1 * * * * * * * 0], it has quality 0.25, wins =1, losses = 2
# [1 * * *  * 0 0 *  * * * 1  * * * *  * * * 0]
# The ps is [0 * 0 * * * * * 1 * * * * 0 * 1 * * * *], it has quality 0.25, wins =3, losses = 8
# [0 * 0 *  * * * *  1 * * *  * 0 * 1  * * * *]
# The ps is [* * * 0 * * * 1 * 1 * 0 * * 1 * * * * *], it has quality 0.24324324324324326, wins =9, losses = 27
# [* * * 0  * * * 1  * 1 * 0  * * 1 *  * * * *]
# The ps is [* 1 * * * 1 * * * * 1 * * 0 * * * 0 * *], it has quality 0.225, wins =9, losses = 30
# [* 1 * *  * 1 * *  * * 1 *  * 0 * *  * 0 * *]
# The ps is [* 0 1 0 * * * * * 1 * * * * * * * 0 * *], it has quality 0.2, wins =2, losses = 7
# [* 0 1 0  * * * *  * 1 * *  * * * *  * 0 * *]
# The ps is [0 * 1 * * 0 * * 1 * * * * * * * * * 0 *], it has quality 0.18181818181818182, wins =2, losses = 8
# [0 * 1 *  * 0 * *  1 * * *  * * * *  * * 0 *]
# The ps is [1 0 * * * * * 1 0 * 1 * * * * * * * * *], it has quality 0.17777777777777778, wins =8, losses = 36
# [1 0 * *  * * * 1  0 * 1 *  * * * *  * * * *]
# The ps is [* 0 * * 1 * * * * * * 1 * 1 * * * 0 * *], it has quality 0.175, wins =7, losses = 32
# [* 0 * *  1 * * *  * * * 1  * 1 * *  * 0 * *]
# The ps is [* 0 * 0 * * * * * * * * * 1 * 0 * * * 1], it has quality 0.16666666666666666, wins =6, losses = 29
# [* 0 * 0  * * * *  * * * *  * 1 * 0  * * * 1]
# The ps is [* 0 * 0 * * * 1 * * * * * * * * * 0 0 *], it has quality 0.15384615384615385, wins =2, losses = 10
# [* 0 * 0  * * * 1  * * * *  * * * *  * 0 0 *]
# The ps is [* 1 0 * * * * * * 0 * * 1 * * * 1 * * *], it has quality 0.15151515151515152, wins =5, losses = 27
# [* 1 0 *  * * * *  * 0 * *  1 * * *  1 * * *]
# The ps is [* * 1 * 0 * * * * * 0 * * 0 1 * * * * *], it has quality 0.14285714285714285, wins =2, losses = 11
# [* * 1 *  0 * * *  * * 0 *  * 0 1 *  * * * *]
# The ps is [* * * * * 1 * * * * * * 0 0 * * 0 * * 0], it has quality 0.14285714285714285, wins =1, losses = 5
# [* * * *  * 1 * *  * * * *  0 0 * *  0 * * 0]
# The ps is [* * 0 1 * 0 * * 0 * * * * * * * 1 * * *], it has quality 0.14285714285714285, wins =1, losses = 5
# [* * 0 1  * 0 * *  0 * * *  * * * *  1 * * *]
# The ps is [1 0 * 0 1 * * * * 0 * * * * * * * * * *], it has quality 0.125, wins =3, losses = 20
# [1 0 * 0  1 * * *  * 0 * *  * * * *  * * * *]
# The ps is [* * 0 * * * 1 * * 1 0 * * * * 1 * * * *], it has quality 0.11428571428571428, wins =4, losses = 30
# [* * 0 *  * * 1 *  * 1 0 *  * * * 1  * * * *]
# The ps is [1 * 1 * * 0 * 1 * * * * * * * * * 0 * *], it has quality 0.1111111111111111, wins =2, losses = 15
# [1 * 1 *  * 0 * 1  * * * *  * * * *  * 0 * *]
# The ps is [* * * 1 * * * * * 0 * 1 * 0 1 * * * * *], it has quality 0.10344827586206896, wins =3, losses = 25
# [* * * 1  * * * *  * 0 * 1  * 0 1 *  * * * *]
# The ps is [* * * * 1 * * 0 * * * 1 * * * * 0 * * 1], it has quality 0.0967741935483871, wins =3, losses = 27
# [* * * *  1 * * 0  * * * 1  * * * *  0 * * 1]
# The ps is [* 1 * * * 0 0 * * * * * * 0 * * * * 0 *], it has quality 0.08333333333333333, wins =1, losses = 10
# [* 1 * *  * 0 0 *  * * * *  * 0 * *  * * 0 *]
# The ps is [* * 1 * * * * * * * * * * 0 * * 1 * 0 1], it has quality 0.08108108108108109, wins =3, losses = 33
# [* * 1 *  * * * *  * * * *  * 0 * *  1 * 0 1]
# The ps is [1 * * * * * * * 1 * 0 * * * 1 * * 0 * *], it has quality 0.06060606060606061, wins =2, losses = 30
# [1 * * *  * * * *  1 * 0 *  * * 1 *  * 0 * *]
# The ps is [* 0 0 1 * 1 * * * * * * * 0 * * * * * *], it has quality 0.05555555555555555, wins =1, losses = 16
# [* 0 0 1  * 1 * *  * * * *  * 0 * *  * * * *]
# The ps is [1 * 0 * 0 * * * * * 0 * * * * * * * 0 *], it has quality 0.0, wins =0, losses = 4
# [1 * 0 *  0 * * *  * * 0 *  * * * *  * * 0 *]
# The ps is [1 0 * * * 0 * * * 0 * 1 * * * * * * * *], it has quality 0.0, wins =0, losses = 10
# [1 0 * *  * 0 * *  * 0 * 1  * * * *  * * * *]
# The ps is [1 0 0 * * * * * * * 0 1 * * * * * * * *], it has quality 0.0, wins =0, losses = 24
# [1 0 0 *  * * * *  * * 0 1  * * * *  * * * *]
# The ps is [* 0 * 0 * 1 * 0 * * 0 * * * * * * * * *], it has quality 0.0, wins =0, losses = 10
# [* 0 * 0  * 1 * 0  * * 0 *  * * * *  * * * *]
# The ps is [0 * * 0 * * * 0 * * * 0 1 * * * * * * *], it has quality 0.0, wins =0, losses = 9
# [0 * * 0  * * * 0  * * * 0  1 * * *  * * * *]
# The ps is [1 0 * * * * 0 * * 1 * * * * 0 * * * * *], it has quality 0.0, wins =0, losses = 6
# [1 0 * *  * * 0 *  * 1 * *  * * 0 *  * * * *]
# The ps is [* * * * * * 1 0 * * 0 * 0 * 1 * * * * *], it has quality 0.0, wins =0, losses = 13
# [* * * *  * * 1 0  * * 0 *  0 * 1 *  * * * *]
# The ps is [* * 0 * * 0 * * 1 1 0 * * * * * * * * *], it has quality 0.0, wins =0, losses = 17
# [* * 0 *  * 0 * *  1 1 0 *  * * * *  * * * *]
# The ps is [* * 0 * * * 0 * * 0 1 * * * * * * 0 * *], it has quality 0.0, wins =0, losses = 16
# [* * 0 *  * * 0 *  * 0 1 *  * * * *  * 0 * *]
# The ps is [* 1 0 0 * * * * * * * * 0 1 * * * * * *], it has quality 0.0, wins =0, losses = 7
# [* 1 0 0  * * * *  * * * *  0 1 * *  * * * *]
# The ps is [* * 1 0 1 0 * * * * 0 * * * * * * * * *], it has quality 0.0, wins =0, losses = 20
# [* * 1 0  1 0 * *  * * 0 *  * * * *  * * * *]
# The ps is [* 0 0 1 * * * 0 * * * * * * 0 * * * * *], it has quality 0.0, wins =0, losses = 4
# [* 0 0 1  * * * 0  * * * *  * * 0 *  * * * *]
# The ps is [0 * * * * * * * * * * * * 0 0 1 0 * * *], it has quality 0.0, wins =0, losses = 13
# [0 * * *  * * * *  * * * *  * 0 0 1  0 * * *]
# The ps is [* 0 * * * * * 0 * * * * * 0 * * * 0 1 *], it has quality 0.0, wins =0, losses = 8
# [* 0 * *  * * * 0  * * * *  * 0 * *  * 0 1 *]
# The ps is [* * * 0 0 * * * * * * * * 0 * 1 * * 1 *], it has quality 0.0, wins =0, losses = 3
# [* * * 0  0 * * *  * * * *  * 0 * 1  * * 1 *]
# The ps is [* * 0 * 1 * 1 0 * * * * * * * * * * * 1], it has quality 0.0, wins =0, losses = 26
# [* * 0 *  1 * 1 0  * * * *  * * * *  * * * 1]
# The ps is [0 * 0 1 * * * 0 * * * * * * * 0 * * * *], it has quality 0.0, wins =0, losses = 9
# [0 * 0 1  * * * 0  * * * *  * * * 0  * * * *]
# The ps is [* 0 * * * * * * * * * * 0 0 0 0 * * * *], it has quality 0.0, wins =0, losses = 8
# [* 0 * *  * * * *  * * * *  0 0 0 0  * * * *]
# The ps is [* * * * * * 0 * * * 1 0 * 0 1 * * * * *], it has quality 0.0, wins =0, losses = 11
# [* * * *  * * 0 *  * * 1 0  * 0 1 *  * * * *]
# The ps is [* * * * * * 0 * * * 1 0 * * * * 0 0 * *], it has quality 0.0, wins =0, losses = 3
# [* * * *  * * 0 *  * * 1 0  * * * *  0 0 * *]
# The ps is [* * 0 1 * * * 0 * * * * * 1 * * * * * 0], it has quality 0.0, wins =0, losses = 9
# [* * 0 1  * * * 0  * * * *  * 1 * *  * * * 0]
# The ps is [* * * 0 * * * * * * * * 0 * * 0 * 1 0 *], it has quality 0.0, wins =0, losses = 4
# [* * * 0  * * * *  * * * *  0 * * 0  * 1 0 *]
# The ps is [* * 1 0 * 0 * * * * * * 0 * * 1 * * * *], it has quality 0.0, wins =0, losses = 16
# [* * 1 0  * 0 * *  * * * *  0 * * 1  * * * *]
# The ps is [* * 0 1 * * * * 0 * * 1 * * * * * * * 0], it has quality 0.0, wins =0, losses = 9
# [* * 0 1  * * * *  0 * * 1  * * * *  * * * 0]
# The ps is [0 * * * * 0 * * * * 0 * 0 * * * * * * 0], it has quality 0.0, wins =0, losses = 11
# [0 * * *  * 0 * *  * * 0 *  0 * * *  * * * 0]
# The ps is [* * * * * 0 0 * * * * 0 * * * * * 0 1 *], it has quality 0.0, wins =0, losses = 1
# [* * * *  * 0 0 *  * * * 0  * * * *  * 0 1 *]
# The ps is [0 * * * * * 0 * * 0 0 0 * * * * * * * *], it has quality 0.0, wins =0, losses = 7
# [0 * * *  * * 0 *  * 0 0 0  * * * *  * * * *]
# The ps is [* * 0 * 0 * * * * * 0 * 1 0 * * * * * *], it has quality 0.0, wins =0, losses = 16
# [* * 0 *  0 * * *  * * 0 *  1 0 * *  * * * *]
# The ps is [* * * 1 * 0 1 * * * * 0 * * * * 0 * * *], it has quality 0.0, wins =0, losses = 11
# [* * * 1  * 0 1 *  * * * 0  * * * *  0 * * *]
# The ps is [* * * * * * 0 * 0 * * 1 * * * * * 0 * 1], it has quality 0.0, wins =0, losses = 3
# [* * * *  * * 0 *  0 * * 1  * * * *  * 0 * 1]

# %%
from SimplifiedSystem.ps_search_utils import run_pymoo_algorithm_with_checks
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.soo.nonconvex.ga import GA
from SimplifiedSystem.Operators.Mutation import GlobalPSUniformMutation
from SimplifiedSystem.Operators.Crossover import GlobalPSUniformCrossover
from SimplifiedSystem.Operators.Sampling import GlobalPSGeometricSampling
from SimplifiedSystem.GlobalPSSearchTask import find_ps_in_problem, GlobalPSSearchTask
from SimplifiedSystem.search_methods import search_global_ps

def inverse_quality(ps: PS):
    return -get_quality_of_ps(ps)

def simplicity(ps: PS):
    return -np.sum(ps.values == STAR)
objectives = [simplicity, inverse_quality]

# construct the optimisation problem instance
pymoo_problem = GlobalPSSearchTask(
    original_problem_search_space=problem.search_space,
    objectives=objectives)

# if there are no operators given, we have these defaults
sampling_operator = GlobalPSGeometricSampling()
crossover_operator = GlobalPSUniformCrossover(prob=0.3)
mutation_operator = GlobalPSUniformMutation(prob=1 / pymoo_problem.n_var,search_space=problem.search_space) 

# the next line of code is a bit odd, but it works! It uses a GA if there is one objective
algorithm = (GA if len(objectives) < 2 else NSGA2)(pop_size=100,
                                                   sampling=sampling_operator,
                                                   crossover=crossover_operator,
                                                   mutation=mutation_operator,
                                                   eliminate_duplicates=True)

pss = run_pymoo_algorithm_with_checks(pymoo_problem=pymoo_problem,
                                      algorithm=algorithm,
                                      reattempts_when_fail=1,
                                      ps_budget=1000,
                                      verbose=True)
# Out:
# C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       82 |      6 |  0.000000E+00 |  0.000000E+00 |             - |             -
#      2 |      182 |      8 |  0.000000E+00 |  0.000000E+00 |  0.0604739392 |             f
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gac8\AppData\Local\Temp\ipykernel_5420\725873748.py", line 34, in <module>
#     pss = run_pymoo_algorithm_with_checks(pymoo_problem=pymoo_problem,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\ps_search_utils.py", line 146, in run_pymoo_algorithm_with_checks
#     pss = run_and_get_results()
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\ps_search_utils.py", line 122, in run_and_get_results
#     res = minimize(pymoo_problem,
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\optimize.py", line 67, in minimize
#     res = algorithm.run()
#           ^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\algorithm.py", line 138, in run
#     self.next()
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\algorithm.py", line 158, in next
#     self.evaluator.eval(self.problem, infills, algorithm=self)
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\evaluator.py", line 69, in eval
#     self._eval(problem, pop[I], evaluate_values_of, **kwargs)
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\evaluator.py", line 90, in _eval
#     out = problem.evaluate(X, return_values_of=evaluate_values_of, return_as_dictionary=True, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\problem.py", line 257, in evaluate
#     _out = self.do(X, return_values_of, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\problem.py", line 299, in do
#     self._evaluate_vectorized(X, out, *args, **kwargs)
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\pymoo\core\problem.py", line 307, in _evaluate_vectorized
#     self._evaluate(X, out, *args, **kwargs)
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\GlobalPSSearchTask.py", line 100, in _evaluate
#     metrics = np.array([self.get_metrics_for_ps(self.individual_to_ps(row)) for row in X])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\GlobalPSSearchTask.py", line 100, in <listcomp>
#     metrics = np.array([self.get_metrics_for_ps(self.individual_to_ps(row)) for row in X])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\GlobalPSSearchTask.py", line 96, in get_metrics_for_ps
#     return [objective(ps) for objective in self.objectives]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\SimplifiedSystem\GlobalPSSearchTask.py", line 96, in <listcomp>
#     return [objective(ps) for objective in self.objectives]
#             ^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\Temp\ipykernel_5420\725873748.py", line 11, in inverse_quality
#     return -get_quality_of_ps(ps)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\Temp\ipykernel_5420\531999849.py", line 50, in get_quality_of_ps
#     wins, losses = get_total_wins_and_losses_for_ps(ps)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\Temp\ipykernel_5420\531999849.py", line 42, in get_total_wins_and_losses_for_ps
#     new_wins, new_losses = get_wins_and_losses_for_solution_and_ps(solution, ps, non_matching_pRef)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\Temp\ipykernel_5420\531999849.py", line 27, in get_wins_and_losses_for_solution_and_ps
#     fitnesses_without_ps = non_matching_pRef.fitnesses_of_observations(pattern_solution_minus_ps)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\PycharmProjects\PSSearch\Core\PRef.py", line -1, in fitnesses_of_observations
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\gac8\AppData\Local\anaconda3\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
import utils

pss.sort(key=lambda ps: ps.metric_scores[1])
simpl = [-ps.metric_scores[0] for ps in pss]
qual = [-ps.metric_scores[1] for ps in pss]


def get_diffs(input_list):
    return [p-h for h, p in zip(input_list[1:], input_list)]

first_derivative = get_diffs(qual)
second_derivative = get_diffs(first_derivative)
first_derivative = [None] +first_derivative
second_derivative = [None, None] + second_derivative
for ps, fd, sd in zip(pss, first_derivative, second_derivative):
    print(ps, fd, sd)
    

from utils import simple_scatterplot


simple_scatterplot(x_label="simpl", y_label = "quality", xs = simpl, ys = qual)
